# %%
#from pandas import *
import pandas as pd

# %% [markdown]
# - Using import * in python programs is considered a bad habit because this way you are polluting your namespace, the import * statement imports all the functions and classes into your own namespace, which may clash with the functions you define or functions of other libraries that you import.

# %% [markdown]
# # To find version

# %%
pd.__version__
# Out:
# '1.3.4'

# %%
#If file is not comma separated and tab separated, we need to tell that file is tab separated using sep='' attribute
#gapminder = pd.read_csv('gapminder.tsv',sep='\t')

# %% [markdown]
# # To import Data set and display first and last 5 rows

# %%
gapminder = pd.read_csv('gapminder.csv')

# %%
gapminder.iloc[4:]
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5     Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6     Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7     Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8     Afghanistan  1992    16317921      Asia    41.674  649.341395
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1700 rows x 6 columns]

# %%
gapminder.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
gapminder.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %% [markdown]
# # To get shape, type and info of dataframe

# %%
#shape is attribute
gapminder.shape
# Out:
# (1704, 6)

# %%
type(gapminder)
# Out:
# pandas.core.frame.DataFrame

# %%
# info() is method
gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
gapminder.dtypes
# Out:
# country        object
# year            int64
# population      int64
# continent      object
# life_exp      float64
# gdp_cap       float64
# dtype: object

# %%
gapminder.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
gapminder.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
gapminder.values
# Out:
# array([['Afghanistan', 1952, 8425333, 'Asia', 28.801, 779.4453145],
#        ['Afghanistan', 1957, 9240934, 'Asia', 30.332, 820.8530296],
#        ['Afghanistan', 1962, 10267083, 'Asia', 31.997, 853.10071],
#        ...,
#        ['Zimbabwe', 1997, 11404948, 'Africa', 46.809, 792.4499603],
#        ['Zimbabwe', 2002, 11926563, 'Africa', 39.989, 672.0386227],
#        ['Zimbabwe', 2007, 12311143, 'Africa', 43.487, 469.7092981]],
#       dtype=object)

# %%
gapminder.values[0]
# Out:
# array(['Afghanistan', 1952, 8425333, 'Asia', 28.801, 779.4453145],
#       dtype=object)

# %%
gapminder.values[10:17]
# Out:
# array([['Afghanistan', 2002, 25268405, 'Asia', 42.129, 726.7340548],
#        ['Afghanistan', 2007, 31889923, 'Asia', 43.828, 974.5803384],
#        ['Albania', 1952, 1282697, 'Europe', 55.23, 1601.056136],
#        ['Albania', 1957, 1476505, 'Europe', 59.28, 1942.284244],
#        ['Albania', 1962, 1728137, 'Europe', 64.82, 2312.888958],
#        ['Albania', 1967, 1984060, 'Europe', 66.22, 2760.196931],
#        ['Albania', 1972, 2263554, 'Europe', 67.69, 3313.422188]],
#       dtype=object)

# %%
gapminder.values[-1]
# Out:
# array(['Zimbabwe', 2007, 12311143, 'Africa', 43.487, 469.7092981],
#       dtype=object)

# %%
gapminder.values[-5:]
# Out:
# array([['Zimbabwe', 1987, 9216418, 'Africa', 62.351, 706.1573059],
#        ['Zimbabwe', 1992, 10704340, 'Africa', 60.377, 693.4207856],
#        ['Zimbabwe', 1997, 11404948, 'Africa', 46.809, 792.4499603],
#        ['Zimbabwe', 2002, 11926563, 'Africa', 39.989, 672.0386227],
#        ['Zimbabwe', 2007, 12311143, 'Africa', 43.487, 469.7092981]],
#       dtype=object)

# %% [markdown]
# # To get last row of dataframe

# %%
#to get last row as series
gapminder.iloc[-1]
# Out:
# country         Zimbabwe
# year                2007
# population      12311143
# continent         Africa
# life_exp          43.487
# gdp_cap       469.709298
# Name: 1703, dtype: object

# %%
#to get last row of pandas dataframe as a dataframe
gapminder.iloc[-1:]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
gapminder.iloc[12:20,1:4]
# Out:
#     year  population continent
# 12  1952     1282697    Europe
# 13  1957     1476505    Europe
# 14  1962     1728137    Europe
# 15  1967     1984060    Europe
# 16  1972     2263554    Europe
# 17  1977     2509048    Europe
# 18  1982     2780097    Europe
# 19  1987     3075321    Europe

# %%
#to get all rows except last row
gapminder.iloc[:-1]
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1698     Zimbabwe  1982     7636524    Africa    60.363  788.855041
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
#
# [1703 rows x 6 columns]

# %%
#to get last row
gapminder.tail(1)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %% [markdown]
# # To get column

# %%
country = gapminder['country']
country.head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
#In Pandas data frame object, each column is really a pandas series and a series is essentially an extension of numpy array 
type(country)
# Out:
# pandas.core.series.Series

# %%
#to get dataframe version
#have to pass python list
#outer square bracket : doing subsetting
#inner aquare bracket : subsetting a list of values, in this case its just one ie country column
country_df = gapminder[['country']]
country_df.head()
# Out:
#        country
# 0  Afghanistan
# 1  Afghanistan
# 2  Afghanistan
# 3  Afghanistan
# 4  Afghanistan

# %%
type(country_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # To drop columns in dataframe

# %%
#gapminder.drop(['continent','country']) #KeyError: "['continent' 'country'] not found in axis"

gapminder_dropped = gapminder.drop(['continent','country'],axis='columns')
#can also use inplace= True, if dont want to assign to new variable here it is gapminder_dropped

# %%
gapminder_dropped
# Out:
#       year  population  life_exp     gdp_cap
# 0     1952     8425333    28.801  779.445314
# 1     1957     9240934    30.332  820.853030
# 2     1962    10267083    31.997  853.100710
# 3     1967    11537966    34.020  836.197138
# 4     1972    13079460    36.088  739.981106
# ...    ...         ...       ...         ...
# 1699  1987     9216418    62.351  706.157306
# 1700  1992    10704340    60.377  693.420786
# 1701  1997    11404948    46.809  792.449960
# 1702  2002    11926563    39.989  672.038623
# 1703  2007    12311143    43.487  469.709298
#
# [1704 rows x 4 columns]

# %%
#gapminder.drop(['continent','country'],axis='columns',inplace=True) #changed in the original dataframe
#gapminder.head()

# %%
gapminder.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %% [markdown]
# # To subset rows using loc and iloc

# %% [markdown]
# loc gets rows (and/or columns) with particular labels.
#
# iloc gets rows (and/or columns) at integer locations.

# %%
gapminder.loc[0]
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# Name: 0, dtype: object

# %%
gapminder.iloc[0]
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# Name: 0, dtype: object

# %%
#gapminder.loc[-1] #key error:-1 # -1 label is not there #loc do string match
gapminder.iloc[-1]
# Out:
# country         Zimbabwe
# year                2007
# population      12311143
# continent         Africa
# life_exp          43.487
# gdp_cap       469.709298
# Name: 1703, dtype: object

# %%
gapminder.loc[[0,1,8,15,2]]
# Out:
#         country  year  population continent  life_exp      gdp_cap
# 0   Afghanistan  1952     8425333      Asia    28.801   779.445314
# 1   Afghanistan  1957     9240934      Asia    30.332   820.853030
# 8   Afghanistan  1992    16317921      Asia    41.674   649.341395
# 15      Albania  1967     1984060    Europe    66.220  2760.196931
# 2   Afghanistan  1962    10267083      Asia    31.997   853.100710

# %%
gapminder.iloc[[0,1,8,15,2,-1]]
# Out:
#           country  year  population continent  life_exp      gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801   779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332   820.853030
# 8     Afghanistan  1992    16317921      Asia    41.674   649.341395
# 15        Albania  1967     1984060    Europe    66.220  2760.196931
# 2     Afghanistan  1962    10267083      Asia    31.997   853.100710
# 1703     Zimbabwe  2007    12311143    Africa    43.487   469.709298

# %%
gapminder.loc[3:5]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360

# %%
gapminder.iloc[3:5]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
subset = gapminder.loc[:, ['year','country']]
subset
# Out:
#       year      country
# 0     1952  Afghanistan
# 1     1957  Afghanistan
# 2     1962  Afghanistan
# 3     1967  Afghanistan
# 4     1972  Afghanistan
# ...    ...          ...
# 1699  1987     Zimbabwe
# 1700  1992     Zimbabwe
# 1701  1997     Zimbabwe
# 1702  2002     Zimbabwe
# 1703  2007     Zimbabwe
#
# [1704 rows x 2 columns]

# %%
subset = gapminder.loc[:, :]
subset
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
subset = gapminder.loc[3:6, ['year','country']]
subset
# Out:
#    year      country
# 3  1967  Afghanistan
# 4  1972  Afghanistan
# 5  1977  Afghanistan
# 6  1982  Afghanistan

# %%
#subset = gapminder.iloc[3:6, ['year','country']] #.iloc requires numeric indexers, got ['year' 'country']
subset = gapminder.iloc[3:6, [2,4]] 
subset
# Out:
#    population  life_exp
# 3    11537966    34.020
# 4    13079460    36.088
# 5    14880372    38.438

# %%
subset = gapminder.iloc[3:6, 2:4] 
subset
# Out:
#    population continent
# 3    11537966      Asia
# 4    13079460      Asia
# 5    14880372      Asia

# %% [markdown]
# # Filtering

# %% [markdown]
# USe loc when you subset both row and column

# %%
gapminder['country'].value_counts()
# Out:
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: country, Length: 142, dtype: int64

# %%
gapminder['continent'].value_counts()
# Out:
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: continent, dtype: int64

# %% [markdown]
# To get unique values in one column

# %%
gapminder.country.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %% [markdown]
# To get count of unique values in one column

# %%
gapminder.country.nunique()
# Out:
# 142

# %%
USA = gapminder.loc[gapminder['country']=='United States']
#USA = gapminder[gapminder['country']=='United States'] #also used
USA
# Out:
#             country  year  population continent  life_exp      gdp_cap
# 1608  United States  1952   157553000  Americas    68.440  13990.48208
# 1609  United States  1957   171984000  Americas    69.490  14847.12712
# 1610  United States  1962   186538000  Americas    70.210  16173.14586
# 1611  United States  1967   198712000  Americas    70.760  19530.36557
# 1612  United States  1972   209896000  Americas    71.340  21806.03594
# 1613  United States  1977   220239000  Americas    73.380  24072.63213
# 1614  United States  1982   232187835  Americas    74.650  25009.55914
# 1615  United States  1987   242803533  Americas    75.020  29884.35041
# 1616  United States  1992   256894189  Americas    76.090  32003.93224
# 1617  United States  1997   272911760  Americas    76.810  35767.43303
# 1618  United States  2002   287675526  Americas    77.310  39097.09955
# 1619  United States  2007   301139947  Americas    78.242  42951.65309

# %%
USA = gapminder.loc[gapminder['country']=='United States',['country','year']]
USA
# Out:
#             country  year
# 1608  United States  1952
# 1609  United States  1957
# 1610  United States  1962
# 1611  United States  1967
# 1612  United States  1972
# 1613  United States  1977
# 1614  United States  1982
# 1615  United States  1987
# 1616  United States  1992
# 1617  United States  1997
# 1618  United States  2002
# 1619  United States  2007

# %%
USA = gapminder.loc[gapminder['country']=='United States',:] # all columns #[row,column]
USA
# Out:
#             country  year  population continent  life_exp      gdp_cap
# 1608  United States  1952   157553000  Americas    68.440  13990.48208
# 1609  United States  1957   171984000  Americas    69.490  14847.12712
# 1610  United States  1962   186538000  Americas    70.210  16173.14586
# 1611  United States  1967   198712000  Americas    70.760  19530.36557
# 1612  United States  1972   209896000  Americas    71.340  21806.03594
# 1613  United States  1977   220239000  Americas    73.380  24072.63213
# 1614  United States  1982   232187835  Americas    74.650  25009.55914
# 1615  United States  1987   242803533  Americas    75.020  29884.35041
# 1616  United States  1992   256894189  Americas    76.090  32003.93224
# 1617  United States  1997   272911760  Americas    76.810  35767.43303
# 1618  United States  2002   287675526  Americas    77.310  39097.09955
# 1619  United States  2007   301139947  Americas    78.242  42951.65309

# %%
#gapminder.loc[gapminder['country']=='United States' & gapminder['year']==1982] #TypeError: Cannot perform 'rand_' with a dtyped [int64] array and scalar of type [bool]
gapminder.loc[(gapminder['country']=='United States') & (gapminder['year']==1982)]
# Out:
#             country  year  population continent  life_exp      gdp_cap
# 1614  United States  1982   232187835  Americas     74.65  25009.55914

# %% [markdown]
# # Groupby:It allows you to split your data into separate groups to perform computations for better analysis

# %%
graph = gapminder.groupby('year')['life_exp'].mean()
graph
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: life_exp, dtype: float64

# %%
import matplotlib.pyplot as plt
graph = gapminder.groupby('year')['life_exp'].mean()
plt.plot(graph)

# %%
gapminder.groupby(['country','year'])['life_exp'].mean()
# Out:
# country      year
# Afghanistan  1952    28.801
#              1957    30.332
#              1962    31.997
#              1967    34.020
#              1972    36.088
#                       ...
# Zimbabwe     1987    62.351
#              1992    60.377
#              1997    46.809
#              2002    39.989
#              2007    43.487
# Name: life_exp, Length: 1704, dtype: float64

# %%
gapminder.groupby(['year','country'])['life_exp'].mean()
# Out:
# year  country
# 1952  Afghanistan           28.801
#       Albania               55.230
#       Algeria               43.077
#       Angola                30.015
#       Argentina             62.485
#                              ...
# 2007  Vietnam               74.249
#       West Bank and Gaza    73.422
#       Yemen, Rep.           62.698
#       Zambia                42.384
#       Zimbabwe              43.487
# Name: life_exp, Length: 1704, dtype: float64

# %%
import numpy as np
gapminder.groupby('year')['life_exp'].agg(np.std)
# Out:
# year
# 1952    12.225956
# 1957    12.231286
# 1962    12.097245
# 1967    11.718858
# 1972    11.381953
# 1977    11.227229
# 1982    10.770618
# 1987    10.556285
# 1992    11.227380
# 1997    11.559439
# 2002    12.279823
# 2007    12.073021
# Name: life_exp, dtype: float64

# %%
gapminder.groupby(['year','continent'])[['life_exp','gdp_cap']].agg(np.mean)
# Out:
#                  life_exp       gdp_cap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# 1967 Africa     45.334538   2050.363801
#      Americas   60.410920   5668.253496
#      Asia       54.663640   5971.173374
#      Europe     69.737600  10143.823757
#      Oceania    71.310000  14495.021790
# 1972 Africa     47.450942   2339.615674
#      Americas   62.394920   6491.334139
# ...

# %%
gapminder.groupby(['year','continent'])[['life_exp','gdp_cap']].agg(np.mean).reset_index() #toget dataframe back
# Out:
#     year continent   life_exp       gdp_cap
# 0   1952    Africa  39.135500   1252.572466
# 1   1952  Americas  53.279840   4079.062552
# 2   1952      Asia  46.314394   5195.484004
# 3   1952    Europe  64.408500   5661.057435
# 4   1952   Oceania  69.255000  10298.085650
# 5   1957    Africa  41.266346   1385.236062
# 6   1957  Americas  55.960280   4616.043733
# 7   1957      Asia  49.318544   5787.732940
# 8   1957    Europe  66.703067   6963.012816
# 9   1957   Oceania  70.295000  11598.522455
# 10  1962    Africa  43.319442   1598.078825
# 11  1962  Americas  58.398760   4901.541870
# 12  1962      Asia  51.563223   5729.369625
# 13  1962    Europe  68.539233   8365.486814
# 14  1962   Oceania  71.085000  12696.452430
# 15  1967    Africa  45.334538   2050.363801
# 16  1967  Americas  60.410920   5668.253496
# 17  1967      Asia  54.663640   5971.173374
# 18  1967    Europe  69.737600  10143.823757
# 19  1967   Oceania  71.310000  14495.021790
# ...
